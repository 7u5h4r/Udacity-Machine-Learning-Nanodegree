# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 5
sample_id = 9999
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 5:
# Samples: 10000
# Label Counts: {0: 1014, 1: 1014, 2: 952, 3: 1016, 4: 997, 5: 1025, 6: 980, 7: 977, 8: 1003, 9: 1022}
# First 20 Labels: [1, 8, 5, 1, 5, 7, 4, 3, 8, 2, 7, 2, 0, 1, 5, 9, 6, 2, 0, 8]
#
# Example of Image 9999:
# Image - Min Value: 4 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    return (x-x.min())/(x.max()-x.min())


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# **Hint:**
#
# Look into LabelBinarizer in the preprocessing module of sklearn.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    return np.eye(10)[x]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    h=image_shape[0]
    w=image_shape[1]
    d=image_shape[2]
    t=tf.placeholder(tf.float32,shape=(None,h,w,d),name='x')
    return t


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    t=tf.placeholder(tf.float32,shape=(None,n_classes),name='y')
    return t


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    t=tf.placeholder(tf.float32,name='keep_prob')
    return t


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.
#
# ** Hint: **
#
# When unpacking values as an argument in Python, look into the [unpacking](https://docs.python.org/3/tutorial/controlflow.html#unpacking-argument-lists) operator.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    print(conv_strides)
    print(pool_strides)
    print(x_tensor)
    c1,c2,p1,p2=conv_strides[0], conv_strides[1],pool_strides[0], pool_strides[1]
    
    
    we = list(conv_ksize) + [x_tensor.get_shape().as_list()[3], conv_num_outputs]
    
    w = tf.Variable(tf.truncated_normal(we, stddev=5e-2))
    b = tf.Variable(tf.zeros(conv_num_outputs))
    
    o = tf.nn.conv2d(x_tensor, w,
                          strides=[1,c1,c2,1],
                          padding='SAME')
    
    o = tf.nn.bias_add(o, b)
    o = tf.nn.relu(o)
    
    o = tf.nn.max_pool(o, 
                            ksize=[1,p1, p2, 1], 
                            strides=[1,p1,p2,1],
                            padding='SAME')
    return o


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# (4, 4)
# (2, 2)
# Tensor("Placeholder_18:0", shape=(?, 32, 32, 5), dtype=float32)
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    print(x_tensor.get_shape().as_list())
    [b,h,w,d]=x_tensor.get_shape().as_list()
    m=[-1,h*w*d]
    return tf.reshape(x_tensor, m)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# [None, 10, 30, 6]
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    [b,w]=x_tensor.get_shape().as_list()
    wght=tf.Variable(tf.truncated_normal(([w, num_outputs]), stddev=0.04))
    bs = tf.Variable(tf.zeros(num_outputs))
    o = tf.add(tf.matmul(x_tensor, wght), bs)
    t=tf.nn.relu(o)
    return t


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    [b,w]=x_tensor.get_shape().as_list()
    wght=tf.Variable(tf.truncated_normal(([w, num_outputs]), stddev=0.04))
    bs = tf.Variable(tf.zeros(num_outputs))
    o = tf.nn.bias_add(tf.matmul(x_tensor,wght), bs)
    return o


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    n = 3
    cnum = [16, 32, 64]
    ck = [[4, 4], [4, 4], [4, 4]]
    cs = [[1, 1], [1, 1], [1, 1]]
    pk = [[2, 2], [2, 2], [2, 2]]
    ps = [[2, 2], [2, 2], [2, 2]]
    
    cl = x
    for i in range(n):
        cl = conv2d_maxpool(
            cl,
            cnum[i],
            ck[i],
            cs[i],
            pk[i],
            ps[i]
        )

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    fl=flatten(cl)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    numfcl = 1
    numo = 10
    
    fcl = fl
    for i in range(numfcl):
        fcl = fully_conn(fcl, numo)
        fcl = tf.nn.dropout(fcl, keep_prob)
        
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    numcl = 10
    o = output(fcl, numcl)
    
    # TODO: return output
    return o


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# [1, 1]
# [2, 2]
# Tensor("x:0", shape=(?, 32, 32, 3), dtype=float32)
# [1, 1]
# [2, 2]
# Tensor("MaxPool:0", shape=(?, 16, 16, 16), dtype=float32)
# [1, 1]
# [2, 2]
# Tensor("MaxPool_1:0", shape=(?, 8, 8, 32), dtype=float32)
# [None, 4, 4, 64]
# [1, 1]
# [2, 2]
# Tensor("Placeholder:0", shape=(?, 32, 32, 3), dtype=float32)
# [1, 1]
# [2, 2]
# Tensor("MaxPool_3:0", shape=(?, 16, 16, 16), dtype=float32)
# [1, 1]
# [2, 2]
# Tensor("MaxPool_4:0", shape=(?, 8, 8, 32), dtype=float32)
# [None, 4, 4, 64]
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x: feature_batch,y:label_batch,keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={x: feature_batch,y: label_batch,keep_prob: 1.0})
    accuracy = session.run(accuracy, feed_dict={x: valid_features,y: valid_labels,keep_prob: 1.0})
    
    print(' Loss : {} '.format(loss))
    print(' Validation Accuracy : {} '.format(accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 60
batch_size = 64
keep_probability = 0.76

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:   Loss : 2.178046226501465
#  Validation Accuracy : 0.20019999146461487
# Epoch  2, CIFAR-10 Batch 1:   Loss : 2.0845141410827637
#  Validation Accuracy : 0.3107999861240387
# Epoch  3, CIFAR-10 Batch 1:   Loss : 1.9713938236236572
#  Validation Accuracy : 0.33539995551109314
# Epoch  4, CIFAR-10 Batch 1:   Loss : 1.962217092514038
#  Validation Accuracy : 0.32819998264312744
# Epoch  5, CIFAR-10 Batch 1:   Loss : 1.9405357837677002
#  Validation Accuracy : 0.3441999852657318
# Epoch  6, CIFAR-10 Batch 1:   Loss : 1.9370498657226562
#  Validation Accuracy : 0.36500000953674316
# Epoch  7, CIFAR-10 Batch 1:   Loss : 1.9243037700653076
#  Validation Accuracy : 0.3781999945640564
# Epoch  8, CIFAR-10 Batch 1:   Loss : 1.867937445640564
#  Validation Accuracy : 0.3830000162124634
# Epoch  9, CIFAR-10 Batch 1:   Loss : 1.8591785430908203
#  Validation Accuracy : 0.4009999632835388
# Epoch 10, CIFAR-10 Batch 1:   Loss : 1.7369201183319092
#  Validation Accuracy : 0.42719998955726624
# Epoch 11, CIFAR-10 Batch 1:   Loss : 1.7850810289382935
#  Validation Accuracy : 0.4244000017642975
# Epoch 12, CIFAR-10 Batch 1:   Loss : 1.702526330947876
#  Validation Accuracy : 0.4431999623775482
# Epoch 13, CIFAR-10 Batch 1:   Loss : 1.704174518585205
#  Validation Accuracy : 0.4389999806880951
# Epoch 14, CIFAR-10 Batch 1:   Loss : 1.612038254737854
#  Validation Accuracy : 0.45619997382164
# Epoch 15, CIFAR-10 Batch 1:   Loss : 1.6440198421478271
#  Validation Accuracy : 0.44279998540878296
# Epoch 16, CIFAR-10 Batch 1:   Loss : 1.504719614982605
#  Validation Accuracy : 0.4609999656677246
# Epoch 17, CIFAR-10 Batch 1:   Loss : 1.5500566959381104
#  Validation Accuracy : 0.4687999486923218
# Epoch 18, CIFAR-10 Batch 1:   Loss : 1.42755126953125
#  Validation Accuracy : 0.48979994654655457
# Epoch 19, CIFAR-10 Batch 1:   Loss : 1.5269367694854736
#  Validation Accuracy : 0.4679999351501465
# Epoch 20, CIFAR-10 Batch 1:   Loss : 1.391370177268982
#  Validation Accuracy : 0.4787999391555786
# Epoch 21, CIFAR-10 Batch 1:   Loss : 1.3801366090774536
#  Validation Accuracy : 0.48559993505477905
# Epoch 22, CIFAR-10 Batch 1:   Loss : 1.3404606580734253
#  Validation Accuracy : 0.49939996004104614
# Epoch 23, CIFAR-10 Batch 1:   Loss : 1.2295236587524414
#  Validation Accuracy : 0.5031999945640564
# Epoch 24, CIFAR-10 Batch 1:   Loss : 1.198007345199585
#  Validation Accuracy : 0.5095999240875244
# Epoch 25, CIFAR-10 Batch 1:   Loss : 1.1933586597442627
#  Validation Accuracy : 0.5165999531745911
# Epoch 26, CIFAR-10 Batch 1:   Loss : 1.1439610719680786
#  Validation Accuracy : 0.5072000026702881
# Epoch 27, CIFAR-10 Batch 1:   Loss : 1.1697094440460205
#  Validation Accuracy : 0.4999999403953552
# Epoch 28, CIFAR-10 Batch 1:   Loss : 1.0705636739730835
#  Validation Accuracy : 0.5139999389648438
# Epoch 29, CIFAR-10 Batch 1:   Loss : 1.053224802017212
#  Validation Accuracy : 0.512999951839447
# Epoch 30, CIFAR-10 Batch 1:   Loss : 0.9862638711929321
#  Validation Accuracy : 0.5183998942375183
# Epoch 31, CIFAR-10 Batch 1:   Loss : 0.966267466545105
#  Validation Accuracy : 0.5279999375343323
# Epoch 32, CIFAR-10 Batch 1:   Loss : 0.8946434855461121
#  Validation Accuracy : 0.5267999172210693
# Epoch 33, CIFAR-10 Batch 1:   Loss : 0.8671250343322754
#  Validation Accuracy : 0.5297999382019043
# Epoch 34, CIFAR-10 Batch 1:   Loss : 0.8640282154083252
#  Validation Accuracy : 0.5080000162124634
# Epoch 35, CIFAR-10 Batch 1:   Loss : 0.735672116279602
#  Validation Accuracy : 0.5381999015808105
# Epoch 36, CIFAR-10 Batch 1:   Loss : 0.7346852421760559
#  Validation Accuracy : 0.5297999382019043
# Epoch 37, CIFAR-10 Batch 1:   Loss : 0.7934039831161499
#  Validation Accuracy : 0.5313999056816101
# Epoch 38, CIFAR-10 Batch 1:   Loss : 0.701528787612915
#  Validation Accuracy : 0.5233999490737915
# Epoch 39, CIFAR-10 Batch 1:   Loss : 0.5790731906890869
#  Validation Accuracy : 0.5237999558448792
# Epoch 40, CIFAR-10 Batch 1:   Loss : 0.608384907245636
#  Validation Accuracy : 0.5261999368667603
# Epoch 41, CIFAR-10 Batch 1:   Loss : 0.5714666843414307
#  Validation Accuracy : 0.5243999361991882
# Epoch 42, CIFAR-10 Batch 1:   Loss : 0.6554641723632812
#  Validation Accuracy : 0.5287999510765076
# Epoch 43, CIFAR-10 Batch 1:   Loss : 0.5730213522911072
#  Validation Accuracy : 0.5199999809265137
# Epoch 44, CIFAR-10 Batch 1:   Loss : 0.5304113030433655
#  Validation Accuracy : 0.5003999471664429
# Epoch 45, CIFAR-10 Batch 1:   Loss : 0.5067907571792603
#  Validation Accuracy : 0.5171999335289001
# Epoch 46, CIFAR-10 Batch 1:   Loss : 0.4848719537258148
#  Validation Accuracy : 0.5343999266624451
# Epoch 47, CIFAR-10 Batch 1:   Loss : 0.5171164274215698
#  Validation Accuracy : 0.5205999612808228
# Epoch 48, CIFAR-10 Batch 1:   Loss : 0.48189958930015564
#  Validation Accuracy : 0.5283999443054199
# Epoch 49, CIFAR-10 Batch 1:   Loss : 0.4531044065952301
#  Validation Accuracy : 0.5305999517440796
# Epoch 50, CIFAR-10 Batch 1:   Loss : 0.5023666024208069
#  Validation Accuracy : 0.5345999598503113
# Epoch 51, CIFAR-10 Batch 1:   Loss : 0.414584219455719
#  Validation Accuracy : 0.5341999530792236
# Epoch 52, CIFAR-10 Batch 1:   Loss : 0.4580514132976532
#  Validation Accuracy : 0.5291999578475952
# Epoch 53, CIFAR-10 Batch 1:   Loss : 0.40236541628837585
#  Validation Accuracy : 0.5189999341964722
# Epoch 54, CIFAR-10 Batch 1:   Loss : 0.4528355598449707
#  Validation Accuracy : 0.5321999788284302
# Epoch 55, CIFAR-10 Batch 1:   Loss : 0.35336777567863464
#  Validation Accuracy : 0.5333999395370483
# Epoch 56, CIFAR-10 Batch 1:   Loss : 0.4144178032875061
#  Validation Accuracy : 0.5343999862670898
# Epoch 57, CIFAR-10 Batch 1:   Loss : 0.4041796922683716
#  Validation Accuracy : 0.5349999666213989
# Epoch 58, CIFAR-10 Batch 1:   Loss : 0.38965338468551636
#  Validation Accuracy : 0.5257999300956726
# Epoch 59, CIFAR-10 Batch 1:   Loss : 0.38663333654403687
#  Validation Accuracy : 0.5253999829292297
# Epoch 60, CIFAR-10 Batch 1:   Loss : 0.3643811345100403
#  Validation Accuracy : 0.5381999611854553

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:   Loss : 2.1591594219207764
#  Validation Accuracy : 0.26819998025894165
# Epoch  1, CIFAR-10 Batch 2:   Loss : 1.9792214632034302
#  Validation Accuracy : 0.2935999929904938
# Epoch  1, CIFAR-10 Batch 3:   Loss : 1.6825854778289795
#  Validation Accuracy : 0.3199999928474426
# Epoch  1, CIFAR-10 Batch 4:   Loss : 1.7711249589920044
#  Validation Accuracy : 0.34859997034072876
# Epoch  1, CIFAR-10 Batch 5:   Loss : 1.8140192031860352
#  Validation Accuracy : 0.36459997296333313
# Epoch  2, CIFAR-10 Batch 1:   Loss : 1.918051838874817
#  Validation Accuracy : 0.3831999599933624
# Epoch  2, CIFAR-10 Batch 2:   Loss : 1.8097761869430542
#  Validation Accuracy : 0.3869999647140503
# Epoch  2, CIFAR-10 Batch 3:   Loss : 1.4445066452026367
#  Validation Accuracy : 0.4095999598503113
# Epoch  2, CIFAR-10 Batch 4:   Loss : 1.6254866123199463
#  Validation Accuracy : 0.43299996852874756
# Epoch  2, CIFAR-10 Batch 5:   Loss : 1.7425153255462646
#  Validation Accuracy : 0.41499996185302734
# Epoch  3, CIFAR-10 Batch 1:   Loss : 1.7762598991394043
#  Validation Accuracy : 0.4591999650001526
# Epoch  3, CIFAR-10 Batch 2:   Loss : 1.7260477542877197
#  Validation Accuracy : 0.46279996633529663
# Epoch  3, CIFAR-10 Batch 3:   Loss : 1.3463833332061768
#  Validation Accuracy : 0.45079997181892395
# Epoch  3, CIFAR-10 Batch 4:   Loss : 1.5189238786697388
#  Validation Accuracy : 0.4683999717235565
# Epoch  3, CIFAR-10 Batch 5:   Loss : 1.582808256149292
#  Validation Accuracy : 0.4639999568462372
# Epoch  4, CIFAR-10 Batch 1:   Loss : 1.636976718902588
#  Validation Accuracy : 0.48959994316101074
# Epoch  4, CIFAR-10 Batch 2:   Loss : 1.6515358686447144
#  Validation Accuracy : 0.5017999410629272
# Epoch  4, CIFAR-10 Batch 3:   Loss : 1.2421835660934448
#  Validation Accuracy : 0.48459991812705994
# Epoch  4, CIFAR-10 Batch 4:   Loss : 1.4151766300201416
#  Validation Accuracy : 0.5025999546051025
# Epoch  4, CIFAR-10 Batch 5:   Loss : 1.455846905708313
#  Validation Accuracy : 0.5029999613761902
# Epoch  5, CIFAR-10 Batch 1:   Loss : 1.582460641860962
#  Validation Accuracy : 0.5113999247550964
# Epoch  5, CIFAR-10 Batch 2:   Loss : 1.5630285739898682
#  Validation Accuracy : 0.5303999185562134
# Epoch  5, CIFAR-10 Batch 3:   Loss : 1.195847749710083
#  Validation Accuracy : 0.514799952507019
# Epoch  5, CIFAR-10 Batch 4:   Loss : 1.3183887004852295
#  Validation Accuracy : 0.5275999307632446
# Epoch  5, CIFAR-10 Batch 5:   Loss : 1.4080764055252075
#  Validation Accuracy : 0.5177999138832092
# Epoch  6, CIFAR-10 Batch 1:   Loss : 1.4636703729629517
#  Validation Accuracy : 0.5333999395370483
# Epoch  6, CIFAR-10 Batch 2:   Loss : 1.600008249282837
#  Validation Accuracy : 0.5373998880386353
# Epoch  6, CIFAR-10 Batch 3:   Loss : 1.128920316696167
#  Validation Accuracy : 0.538599967956543
# Epoch  6, CIFAR-10 Batch 4:   Loss : 1.2584526538848877
#  Validation Accuracy : 0.5501999258995056
# Epoch  6, CIFAR-10 Batch 5:   Loss : 1.3182013034820557
#  Validation Accuracy : 0.5417999029159546
# Epoch  7, CIFAR-10 Batch 1:   Loss : 1.3240388631820679
#  Validation Accuracy : 0.5579999685287476
# Epoch  7, CIFAR-10 Batch 2:   Loss : 1.3424066305160522
#  Validation Accuracy : 0.5561999082565308
# Epoch  7, CIFAR-10 Batch 3:   Loss : 1.062138319015503
#  Validation Accuracy : 0.5659999251365662
# Epoch  7, CIFAR-10 Batch 4:   Loss : 1.2008824348449707
#  Validation Accuracy : 0.5711999535560608
# Epoch  7, CIFAR-10 Batch 5:   Loss : 1.2950297594070435
#  Validation Accuracy : 0.5607998967170715
# Epoch  8, CIFAR-10 Batch 1:   Loss : 1.349197268486023
#  Validation Accuracy : 0.5727999210357666
# Epoch  8, CIFAR-10 Batch 2:   Loss : 1.3201183080673218
#  Validation Accuracy : 0.5519999265670776
# Epoch  8, CIFAR-10 Batch 3:   Loss : 1.0804139375686646
#  Validation Accuracy : 0.5603998899459839
# Epoch  8, CIFAR-10 Batch 4:   Loss : 1.106674075126648
#  Validation Accuracy : 0.5911999344825745
# Epoch  8, CIFAR-10 Batch 5:   Loss : 1.1713016033172607
#  Validation Accuracy : 0.5821999311447144
# Epoch  9, CIFAR-10 Batch 1:   Loss : 1.2671808004379272
#  Validation Accuracy : 0.5763999223709106
# Epoch  9, CIFAR-10 Batch 2:   Loss : 1.2076373100280762
#  Validation Accuracy : 0.5899999141693115
# Epoch  9, CIFAR-10 Batch 3:   Loss : 0.9626797437667847
#  Validation Accuracy : 0.5821999311447144
# Epoch  9, CIFAR-10 Batch 4:   Loss : 1.0821747779846191
#  Validation Accuracy : 0.5971999168395996
# Epoch  9, CIFAR-10 Batch 5:   Loss : 1.13213312625885
#  Validation Accuracy : 0.5847999453544617
# Epoch 10, CIFAR-10 Batch 1:   Loss : 1.2399482727050781
#  Validation Accuracy : 0.6001999378204346
# Epoch 10, CIFAR-10 Batch 2:   Loss : 1.165979266166687
#  Validation Accuracy : 0.5749999284744263
# Epoch 10, CIFAR-10 Batch 3:   Loss : 0.9256533980369568
#  Validation Accuracy : 0.5969998836517334
# Epoch 10, CIFAR-10 Batch 4:   Loss : 1.010606050491333
#  Validation Accuracy : 0.60319983959198
# Epoch 10, CIFAR-10 Batch 5:   Loss : 1.0690302848815918
#  Validation Accuracy : 0.5957998633384705
# Epoch 11, CIFAR-10 Batch 1:   Loss : 1.0926923751831055
#  Validation Accuracy : 0.6083998680114746
# Epoch 11, CIFAR-10 Batch 2:   Loss : 1.1164495944976807
#  Validation Accuracy : 0.6029998660087585
# Epoch 11, CIFAR-10 Batch 3:   Loss : 0.8987753391265869
#  Validation Accuracy : 0.6013998985290527
# Epoch 11, CIFAR-10 Batch 4:   Loss : 1.020934820175171
#  Validation Accuracy : 0.6103998422622681
# Epoch 11, CIFAR-10 Batch 5:   Loss : 1.0477114915847778
#  Validation Accuracy : 0.6051998734474182
# Epoch 12, CIFAR-10 Batch 1:   Loss : 1.0267986059188843
#  Validation Accuracy : 0.607999861240387
# Epoch 12, CIFAR-10 Batch 2:   Loss : 1.0788911581039429
#  Validation Accuracy : 0.6081998348236084
# Epoch 12, CIFAR-10 Batch 3:   Loss : 0.9176023006439209
#  Validation Accuracy : 0.5793999433517456
# Epoch 12, CIFAR-10 Batch 4:   Loss : 0.9843813180923462
#  Validation Accuracy : 0.612799882888794
# Epoch 12, CIFAR-10 Batch 5:   Loss : 0.9998785257339478
#  Validation Accuracy : 0.6115999221801758
# Epoch 13, CIFAR-10 Batch 1:   Loss : 1.0842010974884033
#  Validation Accuracy : 0.6065999269485474
# Epoch 13, CIFAR-10 Batch 2:   Loss : 1.05401611328125
#  Validation Accuracy : 0.6193999648094177
# Epoch 13, CIFAR-10 Batch 3:   Loss : 0.890295684337616
#  Validation Accuracy : 0.5971999168395996
# Epoch 13, CIFAR-10 Batch 4:   Loss : 0.9868665933609009
#  Validation Accuracy : 0.6125999093055725
# Epoch 13, CIFAR-10 Batch 5:   Loss : 0.9948948621749878
#  Validation Accuracy : 0.6185998916625977
# Epoch 14, CIFAR-10 Batch 1:   Loss : 1.0047194957733154
#  Validation Accuracy : 0.6157999634742737
# Epoch 14, CIFAR-10 Batch 2:   Loss : 0.9423905611038208
#  Validation Accuracy : 0.6073998808860779
# Epoch 14, CIFAR-10 Batch 3:   Loss : 0.8983417749404907
#  Validation Accuracy : 0.5887999534606934
# Epoch 14, CIFAR-10 Batch 4:   Loss : 0.9058620929718018
#  Validation Accuracy : 0.6095999479293823
# Epoch 14, CIFAR-10 Batch 5:   Loss : 1.0011712312698364
#  Validation Accuracy : 0.616399884223938
# Epoch 15, CIFAR-10 Batch 1:   Loss : 0.9695277810096741
#  Validation Accuracy : 0.6237998604774475
# Epoch 15, CIFAR-10 Batch 2:   Loss : 0.941603422164917
#  Validation Accuracy : 0.6253999471664429
# Epoch 15, CIFAR-10 Batch 3:   Loss : 0.8047335743904114
#  Validation Accuracy : 0.6085999011993408
# Epoch 15, CIFAR-10 Batch 4:   Loss : 0.8701813817024231
#  Validation Accuracy : 0.6215999126434326
# Epoch 15, CIFAR-10 Batch 5:   Loss : 0.9015445709228516
#  Validation Accuracy : 0.609799861907959
# Epoch 16, CIFAR-10 Batch 1:   Loss : 0.902472198009491
#  Validation Accuracy : 0.6189999580383301
# Epoch 16, CIFAR-10 Batch 2:   Loss : 0.953494668006897
#  Validation Accuracy : 0.6267998814582825
# Epoch 16, CIFAR-10 Batch 3:   Loss : 0.8216010928153992
#  Validation Accuracy : 0.6045999526977539
# Epoch 16, CIFAR-10 Batch 4:   Loss : 0.8773703575134277
#  Validation Accuracy : 0.6255998611450195
# Epoch 16, CIFAR-10 Batch 5:   Loss : 0.9531201720237732
#  Validation Accuracy : 0.6141999363899231
# Epoch 17, CIFAR-10 Batch 1:   Loss : 0.8533812761306763
#  Validation Accuracy : 0.627799928188324
# Epoch 17, CIFAR-10 Batch 2:   Loss : 0.8637329339981079
#  Validation Accuracy : 0.6373999118804932
# Epoch 17, CIFAR-10 Batch 3:   Loss : 0.793054461479187
#  Validation Accuracy : 0.610599935054779
# Epoch 17, CIFAR-10 Batch 4:   Loss : 0.8199235796928406
#  Validation Accuracy : 0.6409998536109924
# Epoch 17, CIFAR-10 Batch 5:   Loss : 0.8798772692680359
#  Validation Accuracy : 0.6289998888969421
# Epoch 18, CIFAR-10 Batch 1:   Loss : 0.8005942702293396
#  Validation Accuracy : 0.631199836730957
# Epoch 18, CIFAR-10 Batch 2:   Loss : 0.893705427646637
#  Validation Accuracy : 0.6287999153137207
# Epoch 18, CIFAR-10 Batch 3:   Loss : 0.7796401977539062
#  Validation Accuracy : 0.6273999214172363
# Epoch 18, CIFAR-10 Batch 4:   Loss : 0.8159610033035278
#  Validation Accuracy : 0.6357998847961426
# Epoch 18, CIFAR-10 Batch 5:   Loss : 0.8900914192199707
#  Validation Accuracy : 0.6271998882293701
# Epoch 19, CIFAR-10 Batch 1:   Loss : 0.7660975456237793
#  Validation Accuracy : 0.6323999166488647
# Epoch 19, CIFAR-10 Batch 2:   Loss : 0.8313593864440918
#  Validation Accuracy : 0.6305999159812927
# Epoch 19, CIFAR-10 Batch 3:   Loss : 0.7676051259040833
#  Validation Accuracy : 0.6137999296188354
# Epoch 19, CIFAR-10 Batch 4:   Loss : 0.7707171440124512
#  Validation Accuracy : 0.6391999125480652
# Epoch 19, CIFAR-10 Batch 5:   Loss : 0.8807270526885986
#  Validation Accuracy : 0.6347998976707458
# Epoch 20, CIFAR-10 Batch 1:   Loss : 0.816719114780426
#  Validation Accuracy : 0.6299999356269836
# Epoch 20, CIFAR-10 Batch 2:   Loss : 0.8255867958068848
#  Validation Accuracy : 0.631399929523468
# Epoch 20, CIFAR-10 Batch 3:   Loss : 0.7100838422775269
#  Validation Accuracy : 0.6177998781204224
# Epoch 20, CIFAR-10 Batch 4:   Loss : 0.7637286186218262
#  Validation Accuracy : 0.6419999003410339
# Epoch 20, CIFAR-10 Batch 5:   Loss : 0.8701918125152588
#  Validation Accuracy : 0.6279999017715454
# Epoch 21, CIFAR-10 Batch 1:   Loss : 0.759036660194397
#  Validation Accuracy : 0.6343998908996582
# Epoch 21, CIFAR-10 Batch 2:   Loss : 0.8414572477340698
#  Validation Accuracy : 0.63319993019104
# Epoch 21, CIFAR-10 Batch 3:   Loss : 0.7296717166900635
#  Validation Accuracy : 0.6335998773574829
# Epoch 21, CIFAR-10 Batch 4:   Loss : 0.7465117573738098
#  Validation Accuracy : 0.6401998996734619
# Epoch 21, CIFAR-10 Batch 5:   Loss : 0.8573185801506042
#  Validation Accuracy : 0.6337999105453491
# Epoch 22, CIFAR-10 Batch 1:   Loss : 0.7424566745758057
#  Validation Accuracy : 0.6361998915672302
# Epoch 22, CIFAR-10 Batch 2:   Loss : 0.8042367100715637
#  Validation Accuracy : 0.6277998685836792
# Epoch 22, CIFAR-10 Batch 3:   Loss : 0.715451180934906
#  Validation Accuracy : 0.624799907207489
# Epoch 22, CIFAR-10 Batch 4:   Loss : 0.7254651784896851
#  Validation Accuracy : 0.6445999145507812
# Epoch 22, CIFAR-10 Batch 5:   Loss : 0.7941468954086304
#  Validation Accuracy : 0.626599907875061
# Epoch 23, CIFAR-10 Batch 1:   Loss : 0.7619881629943848
#  Validation Accuracy : 0.6435998678207397
# Epoch 23, CIFAR-10 Batch 2:   Loss : 0.8203919529914856
#  Validation Accuracy : 0.63319993019104
# Epoch 23, CIFAR-10 Batch 3:   Loss : 0.6894956827163696
#  Validation Accuracy : 0.6291999220848083
# Epoch 23, CIFAR-10 Batch 4:   Loss : 0.7480573058128357
#  Validation Accuracy : 0.6291999220848083
# Epoch 23, CIFAR-10 Batch 5:   Loss : 0.7735405564308167
#  Validation Accuracy : 0.6301999092102051
# Epoch 24, CIFAR-10 Batch 1:   Loss : 0.714331865310669
#  Validation Accuracy : 0.6319999098777771
# Epoch 24, CIFAR-10 Batch 2:   Loss : 0.7599372863769531
#  Validation Accuracy : 0.630599856376648
# Epoch 24, CIFAR-10 Batch 3:   Loss : 0.7283096313476562
#  Validation Accuracy : 0.6203998923301697
# Epoch 24, CIFAR-10 Batch 4:   Loss : 0.6936618089675903
#  Validation Accuracy : 0.6381998658180237
# Epoch 24, CIFAR-10 Batch 5:   Loss : 0.8419093489646912
#  Validation Accuracy : 0.6351998448371887
# Epoch 25, CIFAR-10 Batch 1:   Loss : 0.6603940725326538
#  Validation Accuracy : 0.6235998868942261
# Epoch 25, CIFAR-10 Batch 2:   Loss : 0.8078108429908752
#  Validation Accuracy : 0.6307998895645142
# Epoch 25, CIFAR-10 Batch 3:   Loss : 0.6418240070343018
#  Validation Accuracy : 0.6247998476028442
# Epoch 25, CIFAR-10 Batch 4:   Loss : 0.7391908764839172
#  Validation Accuracy : 0.6359999179840088
# Epoch 25, CIFAR-10 Batch 5:   Loss : 0.7421179413795471
#  Validation Accuracy : 0.6275998950004578
# Epoch 26, CIFAR-10 Batch 1:   Loss : 0.6702526211738586
#  Validation Accuracy : 0.6231998801231384
# Epoch 26, CIFAR-10 Batch 2:   Loss : 0.7640317678451538
#  Validation Accuracy : 0.6437998414039612
# Epoch 26, CIFAR-10 Batch 3:   Loss : 0.732955813407898
#  Validation Accuracy : 0.6333999037742615
# Epoch 26, CIFAR-10 Batch 4:   Loss : 0.679343581199646
#  Validation Accuracy : 0.6451998949050903
# Epoch 26, CIFAR-10 Batch 5:   Loss : 0.8700900673866272
#  Validation Accuracy : 0.5947998762130737
# Epoch 27, CIFAR-10 Batch 1:   Loss : 0.5988702774047852
#  Validation Accuracy : 0.6345998644828796
# Epoch 27, CIFAR-10 Batch 2:   Loss : 0.7355235815048218
#  Validation Accuracy : 0.6477998495101929
# Epoch 27, CIFAR-10 Batch 3:   Loss : 0.6790645718574524
#  Validation Accuracy : 0.6315999031066895
# Epoch 27, CIFAR-10 Batch 4:   Loss : 0.7030351161956787
#  Validation Accuracy : 0.6449998617172241
# Epoch 27, CIFAR-10 Batch 5:   Loss : 0.7762085199356079
#  Validation Accuracy : 0.6319999098777771
# Epoch 28, CIFAR-10 Batch 1:   Loss : 0.6559172868728638
#  Validation Accuracy : 0.637799859046936
# Epoch 28, CIFAR-10 Batch 2:   Loss : 0.7708144187927246
#  Validation Accuracy : 0.6409999132156372
# Epoch 28, CIFAR-10 Batch 3:   Loss : 0.6506338119506836
#  Validation Accuracy : 0.6355998516082764
# Epoch 28, CIFAR-10 Batch 4:   Loss : 0.7549680471420288
#  Validation Accuracy : 0.6295998692512512
# Epoch 28, CIFAR-10 Batch 5:   Loss : 0.7528877258300781
#  Validation Accuracy : 0.6319999098777771
# Epoch 29, CIFAR-10 Batch 1:   Loss : 0.6561989784240723
#  Validation Accuracy : 0.6263998746871948
# Epoch 29, CIFAR-10 Batch 2:   Loss : 0.6951492428779602
#  Validation Accuracy : 0.6417998671531677
# Epoch 29, CIFAR-10 Batch 3:   Loss : 0.6542872190475464
#  Validation Accuracy : 0.6383998394012451
# Epoch 29, CIFAR-10 Batch 4:   Loss : 0.6793289184570312
#  Validation Accuracy : 0.6441999077796936
# Epoch 29, CIFAR-10 Batch 5:   Loss : 0.7800755500793457
#  Validation Accuracy : 0.6265999674797058
# Epoch 30, CIFAR-10 Batch 1:   Loss : 0.6915304064750671
#  Validation Accuracy : 0.6303998827934265
# Epoch 30, CIFAR-10 Batch 2:   Loss : 0.6926957964897156
#  Validation Accuracy : 0.6511998772621155
# Epoch 30, CIFAR-10 Batch 3:   Loss : 0.6206094622612
#  Validation Accuracy : 0.6413999199867249
# Epoch 30, CIFAR-10 Batch 4:   Loss : 0.6502628922462463
#  Validation Accuracy : 0.6511998176574707
# Epoch 30, CIFAR-10 Batch 5:   Loss : 0.7931678295135498
#  Validation Accuracy : 0.6133999228477478
# Epoch 31, CIFAR-10 Batch 1:   Loss : 0.662269651889801
#  Validation Accuracy : 0.6343998908996582
# Epoch 31, CIFAR-10 Batch 2:   Loss : 0.69696044921875
#  Validation Accuracy : 0.6471998691558838
# Epoch 31, CIFAR-10 Batch 3:   Loss : 0.6807929277420044
#  Validation Accuracy : 0.6421999335289001
# Epoch 31, CIFAR-10 Batch 4:   Loss : 0.6488564014434814
#  Validation Accuracy : 0.6343998908996582
# Epoch 31, CIFAR-10 Batch 5:   Loss : 0.8214385509490967
#  Validation Accuracy : 0.6089999675750732
# Epoch 32, CIFAR-10 Batch 1:   Loss : 0.631559431552887
#  Validation Accuracy : 0.6343998312950134
# Epoch 32, CIFAR-10 Batch 2:   Loss : 0.756012499332428
#  Validation Accuracy : 0.6469998955726624
# Epoch 32, CIFAR-10 Batch 3:   Loss : 0.633991539478302
#  Validation Accuracy : 0.6351999044418335
# Epoch 32, CIFAR-10 Batch 4:   Loss : 0.6411421895027161
#  Validation Accuracy : 0.6503998637199402
# Epoch 32, CIFAR-10 Batch 5:   Loss : 0.7392356991767883
#  Validation Accuracy : 0.6243999004364014
# Epoch 33, CIFAR-10 Batch 1:   Loss : 0.6212336421012878
#  Validation Accuracy : 0.6427999138832092
# Epoch 33, CIFAR-10 Batch 2:   Loss : 0.635038435459137
#  Validation Accuracy : 0.6507998704910278
# Epoch 33, CIFAR-10 Batch 3:   Loss : 0.5763833522796631
#  Validation Accuracy : 0.6385998725891113
# Epoch 33, CIFAR-10 Batch 4:   Loss : 0.6285493969917297
#  Validation Accuracy : 0.6471999287605286
# Epoch 33, CIFAR-10 Batch 5:   Loss : 0.7162802815437317
#  Validation Accuracy : 0.6177998781204224
# Epoch 34, CIFAR-10 Batch 1:   Loss : 0.5680071711540222
#  Validation Accuracy : 0.6337999105453491
# Epoch 34, CIFAR-10 Batch 2:   Loss : 0.6357355117797852
#  Validation Accuracy : 0.6483998894691467
# Epoch 34, CIFAR-10 Batch 3:   Loss : 0.6107516884803772
#  Validation Accuracy : 0.6375998854637146
# Epoch 34, CIFAR-10 Batch 4:   Loss : 0.5676152110099792
#  Validation Accuracy : 0.6435998678207397
# Epoch 34, CIFAR-10 Batch 5:   Loss : 0.7873189449310303
#  Validation Accuracy : 0.6137999296188354
# Epoch 35, CIFAR-10 Batch 1:   Loss : 0.563818633556366
#  Validation Accuracy : 0.640799880027771
# Epoch 35, CIFAR-10 Batch 2:   Loss : 0.6506741046905518
#  Validation Accuracy : 0.6523998975753784
# Epoch 35, CIFAR-10 Batch 3:   Loss : 0.5936651229858398
#  Validation Accuracy : 0.6297999024391174
# Epoch 35, CIFAR-10 Batch 4:   Loss : 0.6771044731140137
#  Validation Accuracy : 0.6445999145507812
# Epoch 35, CIFAR-10 Batch 5:   Loss : 0.760517954826355
#  Validation Accuracy : 0.6085999608039856
# Epoch 36, CIFAR-10 Batch 1:   Loss : 0.5590475797653198
#  Validation Accuracy : 0.6233998537063599
# Epoch 36, CIFAR-10 Batch 2:   Loss : 0.6579503417015076
#  Validation Accuracy : 0.6423998475074768
# Epoch 36, CIFAR-10 Batch 3:   Loss : 0.6250144243240356
#  Validation Accuracy : 0.6361998915672302
# Epoch 36, CIFAR-10 Batch 4:   Loss : 0.6405836343765259
#  Validation Accuracy : 0.6459999084472656
# Epoch 36, CIFAR-10 Batch 5:   Loss : 0.6677517294883728
#  Validation Accuracy : 0.636199951171875
# Epoch 37, CIFAR-10 Batch 1:   Loss : 0.5590429306030273
#  Validation Accuracy : 0.6219999194145203
# Epoch 37, CIFAR-10 Batch 2:   Loss : 0.6312936544418335
#  Validation Accuracy : 0.6471998691558838
# Epoch 37, CIFAR-10 Batch 3:   Loss : 0.6505296230316162
#  Validation Accuracy : 0.6471998691558838
# Epoch 37, CIFAR-10 Batch 4:   Loss : 0.6383999586105347
#  Validation Accuracy : 0.6451998353004456
# Epoch 37, CIFAR-10 Batch 5:   Loss : 0.666340708732605
#  Validation Accuracy : 0.624799907207489
# Epoch 38, CIFAR-10 Batch 1:   Loss : 0.5609056949615479
#  Validation Accuracy : 0.6351999044418335
# Epoch 38, CIFAR-10 Batch 2:   Loss : 0.6353706121444702
#  Validation Accuracy : 0.6433998942375183
# Epoch 38, CIFAR-10 Batch 3:   Loss : 0.6407057642936707
#  Validation Accuracy : 0.6381998658180237
# Epoch 38, CIFAR-10 Batch 4:   Loss : 0.5840107202529907
#  Validation Accuracy : 0.6423999071121216
# Epoch 38, CIFAR-10 Batch 5:   Loss : 0.6532771587371826
#  Validation Accuracy : 0.6239999532699585
# Epoch 39, CIFAR-10 Batch 1:   Loss : 0.577349841594696
#  Validation Accuracy : 0.6387999057769775
# Epoch 39, CIFAR-10 Batch 2:   Loss : 0.5817328691482544
#  Validation Accuracy : 0.645599901676178
# Epoch 39, CIFAR-10 Batch 3:   Loss : 0.581832766532898
#  Validation Accuracy : 0.6463998556137085
# Epoch 39, CIFAR-10 Batch 4:   Loss : 0.5474547147750854
#  Validation Accuracy : 0.6501998901367188
# Epoch 39, CIFAR-10 Batch 5:   Loss : 0.594668984413147
#  Validation Accuracy : 0.6405999064445496
# Epoch 40, CIFAR-10 Batch 1:   Loss : 0.896638810634613
#  Validation Accuracy : 0.6125999093055725
# Epoch 40, CIFAR-10 Batch 2:   Loss : 0.6270601153373718
#  Validation Accuracy : 0.6417998671531677
# Epoch 40, CIFAR-10 Batch 3:   Loss : 0.6146694421768188
#  Validation Accuracy : 0.6409999132156372
# Epoch 40, CIFAR-10 Batch 4:   Loss : 0.5904515385627747
#  Validation Accuracy : 0.643799901008606
# Epoch 40, CIFAR-10 Batch 5:   Loss : 0.7071300745010376
#  Validation Accuracy : 0.622999906539917
# Epoch 41, CIFAR-10 Batch 1:   Loss : 0.5393733978271484
#  Validation Accuracy : 0.6319999098777771
# Epoch 41, CIFAR-10 Batch 2:   Loss : 0.5561941266059875
#  Validation Accuracy : 0.6481999158859253
# Epoch 41, CIFAR-10 Batch 3:   Loss : 0.5909773111343384
#  Validation Accuracy : 0.6373998522758484
# Epoch 41, CIFAR-10 Batch 4:   Loss : 0.5489864945411682
#  Validation Accuracy : 0.6505998373031616
# Epoch 41, CIFAR-10 Batch 5:   Loss : 0.5940699577331543
#  Validation Accuracy : 0.6439998745918274
# Epoch 42, CIFAR-10 Batch 1:   Loss : 0.542995035648346
#  Validation Accuracy : 0.6433998346328735
# Epoch 42, CIFAR-10 Batch 2:   Loss : 0.5651336312294006
#  Validation Accuracy : 0.6401998996734619
# Epoch 42, CIFAR-10 Batch 3:   Loss : 0.5513666868209839
#  Validation Accuracy : 0.6381998658180237
# Epoch 42, CIFAR-10 Batch 4:   Loss : 0.5949358940124512
#  Validation Accuracy : 0.6389999389648438
# Epoch 42, CIFAR-10 Batch 5:   Loss : 0.5993344783782959
#  Validation Accuracy : 0.6283998489379883
# Epoch 43, CIFAR-10 Batch 1:   Loss : 0.573034405708313
#  Validation Accuracy : 0.6427998542785645
# Epoch 43, CIFAR-10 Batch 2:   Loss : 0.590980052947998
#  Validation Accuracy : 0.6429998874664307
# Epoch 43, CIFAR-10 Batch 3:   Loss : 0.5483745336532593
#  Validation Accuracy : 0.6445999145507812
# Epoch 43, CIFAR-10 Batch 4:   Loss : 0.48644378781318665
#  Validation Accuracy : 0.6497998833656311
# Epoch 43, CIFAR-10 Batch 5:   Loss : 0.6009130477905273
#  Validation Accuracy : 0.6409999132156372
# Epoch 44, CIFAR-10 Batch 1:   Loss : 0.5102188587188721
#  Validation Accuracy : 0.6327998638153076
# Epoch 44, CIFAR-10 Batch 2:   Loss : 0.6045066714286804
#  Validation Accuracy : 0.6279999017715454
# Epoch 44, CIFAR-10 Batch 3:   Loss : 0.5718132853507996
#  Validation Accuracy : 0.6461998820304871
# Epoch 44, CIFAR-10 Batch 4:   Loss : 0.5721856355667114
#  Validation Accuracy : 0.6407999396324158
# Epoch 44, CIFAR-10 Batch 5:   Loss : 0.6013810634613037
#  Validation Accuracy : 0.6457998752593994
# Epoch 45, CIFAR-10 Batch 1:   Loss : 0.5166123509407043
#  Validation Accuracy : 0.6411998867988586
# Epoch 45, CIFAR-10 Batch 2:   Loss : 0.5877602100372314
#  Validation Accuracy : 0.6433998942375183
# Epoch 45, CIFAR-10 Batch 3:   Loss : 0.5767759084701538
#  Validation Accuracy : 0.6321998834609985
# Epoch 45, CIFAR-10 Batch 4:   Loss : 0.48398256301879883
#  Validation Accuracy : 0.6407998204231262
# Epoch 45, CIFAR-10 Batch 5:   Loss : 0.5847574472427368
#  Validation Accuracy : 0.6309998631477356
# Epoch 46, CIFAR-10 Batch 1:   Loss : 0.5302824974060059
#  Validation Accuracy : 0.640799880027771
# Epoch 46, CIFAR-10 Batch 2:   Loss : 0.588119626045227
#  Validation Accuracy : 0.6345999240875244
# Epoch 46, CIFAR-10 Batch 3:   Loss : 0.560665488243103
#  Validation Accuracy : 0.6299999356269836
# Epoch 46, CIFAR-10 Batch 4:   Loss : 0.5225784778594971
#  Validation Accuracy : 0.6401998996734619
# Epoch 46, CIFAR-10 Batch 5:   Loss : 0.5113332271575928
#  Validation Accuracy : 0.6429998874664307
# Epoch 47, CIFAR-10 Batch 1:   Loss : 0.5228878855705261
#  Validation Accuracy : 0.6349998712539673
# Epoch 47, CIFAR-10 Batch 2:   Loss : 0.5403804779052734
#  Validation Accuracy : 0.6475999355316162
# Epoch 47, CIFAR-10 Batch 3:   Loss : 0.622337818145752
#  Validation Accuracy : 0.621999979019165
# Epoch 47, CIFAR-10 Batch 4:   Loss : 0.5087548494338989
#  Validation Accuracy : 0.6367999315261841
# Epoch 47, CIFAR-10 Batch 5:   Loss : 0.5167561173439026
#  Validation Accuracy : 0.6393998861312866
# Epoch 48, CIFAR-10 Batch 1:   Loss : 0.4801384508609772
#  Validation Accuracy : 0.6411998867988586
# Epoch 48, CIFAR-10 Batch 2:   Loss : 0.578950047492981
#  Validation Accuracy : 0.6303998827934265
# Epoch 48, CIFAR-10 Batch 3:   Loss : 0.5638684034347534
#  Validation Accuracy : 0.6349998712539673
# Epoch 48, CIFAR-10 Batch 4:   Loss : 0.49051356315612793
#  Validation Accuracy : 0.6355999112129211
# Epoch 48, CIFAR-10 Batch 5:   Loss : 0.495311439037323
#  Validation Accuracy : 0.6443999409675598
# Epoch 49, CIFAR-10 Batch 1:   Loss : 0.511724054813385
#  Validation Accuracy : 0.6267998814582825
# Epoch 49, CIFAR-10 Batch 2:   Loss : 0.5067242980003357
#  Validation Accuracy : 0.6419998407363892
# Epoch 49, CIFAR-10 Batch 3:   Loss : 0.559466540813446
#  Validation Accuracy : 0.6333998441696167
# Epoch 49, CIFAR-10 Batch 4:   Loss : 0.49200356006622314
#  Validation Accuracy : 0.6333998441696167
# Epoch 49, CIFAR-10 Batch 5:   Loss : 0.49034038186073303
#  Validation Accuracy : 0.6481999158859253
# Epoch 50, CIFAR-10 Batch 1:   Loss : 0.5177035331726074
#  Validation Accuracy : 0.6381999254226685
# Epoch 50, CIFAR-10 Batch 2:   Loss : 0.495213121175766
#  Validation Accuracy : 0.6433998942375183
# Epoch 50, CIFAR-10 Batch 3:   Loss : 0.5724277496337891
#  Validation Accuracy : 0.6333999037742615
# Epoch 50, CIFAR-10 Batch 4:   Loss : 0.4665229618549347
#  Validation Accuracy : 0.6405998468399048
# Epoch 50, CIFAR-10 Batch 5:   Loss : 0.5196034908294678
#  Validation Accuracy : 0.6439998745918274
# Epoch 51, CIFAR-10 Batch 1:   Loss : 0.46457639336586
#  Validation Accuracy : 0.6401998996734619
# Epoch 51, CIFAR-10 Batch 2:   Loss : 0.5129703283309937
#  Validation Accuracy : 0.6365998983383179
# Epoch 51, CIFAR-10 Batch 3:   Loss : 0.5734854340553284
#  Validation Accuracy : 0.6399998664855957
# Epoch 51, CIFAR-10 Batch 4:   Loss : 0.49070969223976135
#  Validation Accuracy : 0.6403998732566833
# Epoch 51, CIFAR-10 Batch 5:   Loss : 0.5636788010597229
#  Validation Accuracy : 0.6467998623847961
# Epoch 52, CIFAR-10 Batch 1:   Loss : 0.4921460449695587
#  Validation Accuracy : 0.6415998339653015
# Epoch 52, CIFAR-10 Batch 2:   Loss : 0.47201108932495117
#  Validation Accuracy : 0.6541998982429504
# Epoch 52, CIFAR-10 Batch 3:   Loss : 0.5716781616210938
#  Validation Accuracy : 0.6257998943328857
# Epoch 52, CIFAR-10 Batch 4:   Loss : 0.5019899606704712
#  Validation Accuracy : 0.6431998610496521
# Epoch 52, CIFAR-10 Batch 5:   Loss : 0.49398499727249146
#  Validation Accuracy : 0.6439998745918274
# Epoch 53, CIFAR-10 Batch 1:   Loss : 0.4465678930282593
#  Validation Accuracy : 0.6373999118804932
# Epoch 53, CIFAR-10 Batch 2:   Loss : 0.5337871313095093
#  Validation Accuracy : 0.6405999064445496
# Epoch 53, CIFAR-10 Batch 3:   Loss : 0.5105288028717041
#  Validation Accuracy : 0.6289998888969421
# Epoch 53, CIFAR-10 Batch 4:   Loss : 0.5149258375167847
#  Validation Accuracy : 0.6355999112129211
# Epoch 53, CIFAR-10 Batch 5:   Loss : 0.4943532943725586
#  Validation Accuracy : 0.650999903678894
# Epoch 54, CIFAR-10 Batch 1:   Loss : 0.4301740527153015
#  Validation Accuracy : 0.6413998603820801
# Epoch 54, CIFAR-10 Batch 2:   Loss : 0.5297036170959473
#  Validation Accuracy : 0.6333999037742615
# Epoch 54, CIFAR-10 Batch 3:   Loss : 0.5411592721939087
#  Validation Accuracy : 0.6477999091148376
# Epoch 54, CIFAR-10 Batch 4:   Loss : 0.4528059661388397
#  Validation Accuracy : 0.6447999477386475
# Epoch 54, CIFAR-10 Batch 5:   Loss : 0.5149750113487244
#  Validation Accuracy : 0.6349999308586121
# Epoch 55, CIFAR-10 Batch 1:   Loss : 0.4585322439670563
#  Validation Accuracy : 0.6429998874664307
# Epoch 55, CIFAR-10 Batch 2:   Loss : 0.49773263931274414
#  Validation Accuracy : 0.6327999234199524
# Epoch 55, CIFAR-10 Batch 3:   Loss : 0.4841575026512146
#  Validation Accuracy : 0.6429998874664307
# Epoch 55, CIFAR-10 Batch 4:   Loss : 0.5088117122650146
#  Validation Accuracy : 0.6317998766899109
# Epoch 55, CIFAR-10 Batch 5:   Loss : 0.5171778202056885
#  Validation Accuracy : 0.6327998638153076
# Epoch 56, CIFAR-10 Batch 1:   Loss : 0.46208733320236206
#  Validation Accuracy : 0.6271998882293701
# Epoch 56, CIFAR-10 Batch 2:   Loss : 0.47302356362342834
#  Validation Accuracy : 0.6443999409675598
# Epoch 56, CIFAR-10 Batch 3:   Loss : 0.5362196564674377
#  Validation Accuracy : 0.6363999247550964
# Epoch 56, CIFAR-10 Batch 4:   Loss : 0.4813646376132965
#  Validation Accuracy : 0.6333998441696167
# Epoch 56, CIFAR-10 Batch 5:   Loss : 0.5039153695106506
#  Validation Accuracy : 0.6309998631477356
# Epoch 57, CIFAR-10 Batch 1:   Loss : 0.44589394330978394
#  Validation Accuracy : 0.6431998610496521
# Epoch 57, CIFAR-10 Batch 2:   Loss : 0.4926674962043762
#  Validation Accuracy : 0.634399950504303
# Epoch 57, CIFAR-10 Batch 3:   Loss : 0.4786309003829956
#  Validation Accuracy : 0.636199951171875
# Epoch 57, CIFAR-10 Batch 4:   Loss : 0.5133336186408997
#  Validation Accuracy : 0.6351999044418335
# Epoch 57, CIFAR-10 Batch 5:   Loss : 0.4599143862724304
#  Validation Accuracy : 0.6433998346328735
# Epoch 58, CIFAR-10 Batch 1:   Loss : 0.48406022787094116
#  Validation Accuracy : 0.6437998414039612
# Epoch 58, CIFAR-10 Batch 2:   Loss : 0.4533960223197937
#  Validation Accuracy : 0.6345999240875244
# Epoch 58, CIFAR-10 Batch 3:   Loss : 0.46693095564842224
#  Validation Accuracy : 0.6391998529434204
# Epoch 58, CIFAR-10 Batch 4:   Loss : 0.4814644455909729
#  Validation Accuracy : 0.6375998258590698
# Epoch 58, CIFAR-10 Batch 5:   Loss : 0.47573980689048767
#  Validation Accuracy : 0.637199878692627
# Epoch 59, CIFAR-10 Batch 1:   Loss : 0.4167066514492035
#  Validation Accuracy : 0.6373999714851379
# Epoch 59, CIFAR-10 Batch 2:   Loss : 0.46610546112060547
#  Validation Accuracy : 0.638999879360199
# Epoch 59, CIFAR-10 Batch 3:   Loss : 0.49016690254211426
#  Validation Accuracy : 0.6461998820304871
# Epoch 59, CIFAR-10 Batch 4:   Loss : 0.4976765513420105
#  Validation Accuracy : 0.6339998841285706
# Epoch 59, CIFAR-10 Batch 5:   Loss : 0.44910913705825806
#  Validation Accuracy : 0.6329998970031738
# Epoch 60, CIFAR-10 Batch 1:   Loss : 0.4361628293991089
#  Validation Accuracy : 0.629599928855896
# Epoch 60, CIFAR-10 Batch 2:   Loss : 0.48821860551834106
#  Validation Accuracy : 0.634199857711792
# Epoch 60, CIFAR-10 Batch 3:   Loss : 0.4552608132362366
#  Validation Accuracy : 0.6397998929023743
# Epoch 60, CIFAR-10 Batch 4:   Loss : 0.47116339206695557
#  Validation Accuracy : 0.6325998902320862
# Epoch 60, CIFAR-10 Batch 5:   Loss : 0.4328725337982178
#  Validation Accuracy : 0.6393998861312866

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.6381369426751592

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. That's because there are many more techniques that can be applied to your model and we recemmond that once you are done with this project, you explore!
#
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
